# %% [markdown]
# <a href="https://colab.research.google.com/github/abidam16/data-analytic-app/blob/main/notebook_analytic.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %% [markdown]
# # Analisis Data E-Commerce Public Dataset

# %% [markdown]
# *   Nama: Abid Ammar Mahdy
# *   E-mail: abidammar1611@gmail.com

# %% [markdown]
# # Pertanyaan Bisnis

# %% [markdown]
# * Dimana kota yang memiliki jumlah seller dan customer tertinggi dan terendah?
# * Berapa pendapatan tertinggi dan terendah dari seller?
# * Bagaimana tingkat penjualan di setiap bulan?
# * Bagaimana RFM analysis pada customer?
# * Barang apa yang paling banyak dan sedikit terjual?
# * Bagaimana umunya para customer membayar setiap pesanannya?
# * Bagaimana rata-rata selisih waktu dari customer menekan pembelian hingga paket sampai ke customer untuk setiap seller?
# * Bagaimana rata-rata selisih waktu paket sampai ke customer dengan estimasi yang ditetapkan untuk setiap seller?
# * Bagaimana penilaian kepuasan pada customer terhadap pesanan yang diterima?

# %% [markdown]
# # Import Library

# %%
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt
import seaborn as sns
import unidecode

# %%
# !unzip /content/E-commerce-public-dataset.zip

# %% [markdown]
# # Data Wrangling

# %% [markdown]
# ## Gathering Data

# %%
customers_data = pd.read_csv('/content/E-Commerce Public Dataset/customers_dataset.csv')
customers_data.sort_values('customer_zip_code_prefix')
# Out:
#                             customer_id                customer_unique_id  \
# 23914  7ae2a9337aa4bc799723511faa1d6830  0c1a20644f0dc126c3eaff8dbc1bd12c
# 11747  a09edf8c1e842e94805a206b3d73eed5  968f6d2f674977d88a4b445a5117ccd8
# 23990  ee9b73e88afb4904ee2322cfc89cf638  095e7c124c5c1ccb1eb9f731152eae6a
# 81634  15d7dbcd027b5b24866db33e2b819021  ddab5650ba76e2fa2d7e25ed3343bd92
# 34298  f3e31afdae80581be48ce94e7b0f3366  ded4351942c7fc292b88e5b090af2b46
# ...                                 ...                               ...
# 17275  f93bb6c70a7306d18a24f77f1889916d  ee0a41f3ec008b1459efbd99c775e6ea
# 41113  3ab8bc00f8740d54afc4c771fb6c7f69  0528a0a940c7116ccb48fdbb8e80a8ff
# 956    964b34423c822e9bd9831635ccc83db2  e49eafd7e69d43b8d86f6b5590fafd02
# 96592  657ba09c6edfbbc09f6054f541ec1f90  3dbb390afed2043063d358900ae05d0d
# 25752  f04c3f6e20a2a4318d97d7cec1d27bbf  8f846b30f8f56368cd1bf4c89efeed74
#
#        customer_zip_code_prefix    customer_city customer_state
# 23914                      1003        sao paulo             SP
# 11747                      1004        sao paulo             SP
# 23990                      1004        sao paulo             SP
# 81634                      1005        sao paulo             SP
# 34298                      1005        sao paulo             SP
# ...                         ...              ...            ...
# 17275                     99965       agua santa             RS
# 41113                     99970          ciriaco             RS
# 956                       99980  david canabarro             RS
# 96592                     99980  david canabarro             RS
# 25752                     99990        muliterno             RS
#
# [99441 rows x 5 columns]

# %%
order_items_data = pd.read_csv('/content/E-Commerce Public Dataset/order_items_dataset.csv')
order_items_data.sort_values('order_id')
# Out:
#                                 order_id  order_item_id  \
# 0       00010242fe8c5a6d1ba2dd792cb16214              1
# 1       00018f77f2f0320c557190d7a144bdd3              1
# 2       000229ec398224ef6ca0657da4fc703e              1
# 3       00024acbcdf0a6daa1e931b038114c75              1
# 4       00042b26cf59d7ce69dfabb4e55b4fd9              1
# ...                                  ...            ...
# 112645  fffc94f6ce00a00581880bf54a75a037              1
# 112646  fffcd46ef2263f404302a634eb57f7eb              1
# 112647  fffce4705a9662cd70adb13d4a31832d              1
# 112648  fffe18544ffabc95dfada21779c9644f              1
# 112649  fffe41c64501cc87c801fd61db3f6244              1
#
#                               product_id                         seller_id  \
# 0       4244733e06e7ecb4970a6e2683c13e61  48436dade18ac8b2bce089ec2a041202
# 1       e5f2d52b802189ee658865ca93d83a8f  dd7ddc04e1b6c2c614352b383efe2d36
# 2       c777355d18b72b67abbeef9df44fd0fd  5b51032eddd242adc84c38acab88f23d
# 3       7634da152a4610f1595efa32f14722fc  9d7a1d34a5052409006425275ba1c2b4
# 4       ac6c3623068f30de03045865e4e10089  df560393f3a51e74553ab94004ba5c87
# ...                                  ...                               ...
# 112645  4aa6014eceb682077f9dc4bffebc05b0  b8bc237ba3788b23da09c0f1f3a3288c
# 112646  32e07fd915822b0765e448c4dd74c828  f3c38ab652836d21de61fb8314b69182
# 112647  72a30483855e2eafc67aee5dc2560482  c3cfdc648177fdbbbb35635a37472c53
# 112648  9c422a519119dcad7575db5af1ba540e  2b3e4a2a3ea8e01938cabda2a3e5cc79
# 112649  350688d9dc1e75ff97be326363655e01  f7ccf836d21b2fb1de37564105216cc1
#
#         shipping_limit_date   price  freight_value
# 0       2017-09-19 09:45:35   58.90          13.29
# 1       2017-05-03 11:05:13  239.90          19.93
# 2       2018-01-18 14:48:30  199.00          17.87
# 3       2018-08-15 10:10:18   12.99          12.79
# 4       2017-02-13 13:57:51  199.90          18.14
# ...                     ...     ...            ...
# 112645  2018-05-02 04:11:01  299.99          43.41
# 112646  2018-07-20 04:31:48  350.00          36.53
# 112647  2017-10-30 17:14:25   99.90          16.95
# 112648  2017-08-21 00:04:32   55.99           8.72
# 112649  2018-06-12 17:10:13   43.00          12.79
#
# [112650 rows x 7 columns]

# %%
order_payments_data = pd.read_csv('/content/E-Commerce Public Dataset/order_payments_dataset.csv')
order_payments_data.sort_values('order_id')
# Out:
#                                order_id  payment_sequential payment_type  \
# 85283  00010242fe8c5a6d1ba2dd792cb16214                   1  credit_card
# 2499   00018f77f2f0320c557190d7a144bdd3                   1  credit_card
# 12393  000229ec398224ef6ca0657da4fc703e                   1  credit_card
# 32971  00024acbcdf0a6daa1e931b038114c75                   1  credit_card
# 98711  00042b26cf59d7ce69dfabb4e55b4fd9                   1  credit_card
# ...                                 ...                 ...          ...
# 69123  fffc94f6ce00a00581880bf54a75a037                   1       boleto
# 2776   fffcd46ef2263f404302a634eb57f7eb                   1       boleto
# 58888  fffce4705a9662cd70adb13d4a31832d                   1  credit_card
# 37089  fffe18544ffabc95dfada21779c9644f                   1  credit_card
# 1235   fffe41c64501cc87c801fd61db3f6244                   1  credit_card
#
#        payment_installments  payment_value
# 85283                     2          72.19
# 2499                      3         259.83
# 12393                     5         216.87
# 32971                     2          25.78
# 98711                     3         218.04
# ...                     ...            ...
# 69123                     1         343.40
# 2776                      1         386.53
# 58888                     3         116.85
# 37089                     3          64.71
# 1235                      1          55.79
#
# [103886 rows x 5 columns]

# %%
order_reviews_data = pd.read_csv('/content/E-Commerce Public Dataset/order_reviews_dataset.csv')
order_reviews_data
# Out:
#                               review_id                          order_id  \
# 0      7bc2406110b926393aa56f80a40eba40  73fc7af87114b39712e6da79b0a377eb
# 1      80e641a11e56f04c1ad469d5645fdfde  a548910a1c6147796b98fdf73dbeba33
# 2      228ce5500dc1d8e020d8d1322874b6f0  f9e4b658b201a9f2ecdecbb34bed034b
# 3      e64fb393e7b32834bb789ff8bb30750e  658677c97b385a9be170737859d3511b
# 4      f7c4243c7fe1938f181bec41a392bdeb  8e6bfb81e283fa7e4f11123a3fb894f1
# ...                                 ...                               ...
# 99219  574ed12dd733e5fa530cfd4bbf39d7c9  2a8c23fee101d4d5662fa670396eb8da
# 99220  f3897127253a9592a73be9bdfdf4ed7a  22ec9f0669f784db00fa86d035cf8602
# 99221  b3de70c89b1510c4cd3d0649fd302472  55d4004744368f5571d1f590031933e4
# 99222  1adeb9d84d72fe4e337617733eb85149  7725825d039fc1f0ceb7635e3f7d9206
# 99223  efe49f1d6f951dd88b51e6ccd4cc548f  90531360ecb1eec2a1fbb265a0db0508
#
#        review_score review_comment_title  \
# 0                 4                  NaN
# 1                 5                  NaN
# 2                 5                  NaN
# 3                 5                  NaN
# 4                 5                  NaN
# ...             ...                  ...
# 99219             5                  NaN
# 99220             5                  NaN
# 99221             5                  NaN
# 99222             4                  NaN
# 99223             1                  NaN
#
#                                   review_comment_message review_creation_date  \
# 0                                                    NaN  2018-01-18 00:00:00
# 1                                                    NaN  2018-03-10 00:00:00
# 2                                                    NaN  2018-02-17 00:00:00
# 3                  Recebi bem antes do prazo estipulado.  2017-04-21 00:00:00
# 4      Parabéns lojas lannister adorei comprar pela I...  2018-03-01 00:00:00
# ...                                                  ...                  ...
# 99219                                                NaN  2018-07-07 00:00:00
# 99220                                                NaN  2017-12-09 00:00:00
# 99221  Excelente mochila, entrega super rápida. Super...  2018-03-22 00:00:00
# 99222                                                NaN  2018-07-01 00:00:00
# 99223  meu produto chegou e ja tenho que devolver, po...  2017-07-03 00:00:00
#
#       review_answer_timestamp
# 0         2018-01-18 21:46:59
# 1         2018-03-11 03:05:13
# 2         2018-02-18 14:36:24
# 3         2017-04-21 22:02:06
# 4         2018-03-02 10:26:53
# ...                       ...
# 99219     2018-07-14 17:18:30
# 99220     2017-12-11 20:06:42
# 99221     2018-03-23 09:10:43
# 99222     2018-07-02 12:59:13
# 99223     2017-07-03 21:01:49
#
# [99224 rows x 7 columns]

# %%
orders_data = pd.read_csv('/content/E-Commerce Public Dataset/orders_dataset.csv')
orders_data
# Out:
#                                order_id                       customer_id  \
# 0      e481f51cbdc54678b7cc49136f2d6af7  9ef432eb6251297304e76186b10a928d
# 1      53cdb2fc8bc7dce0b6741e2150273451  b0830fb4747a6c6d20dea0b8c802d7ef
# 2      47770eb9100c2d0c44946d9cf07ec65d  41ce2a54c0b03bf3443c3d931a367089
# 3      949d5b44dbf5de918fe9c16f97b45f8a  f88197465ea7920adcdbec7375364d82
# 4      ad21c59c0840e6cb83a9ceb5573f8159  8ab97904e6daea8866dbdbc4fb7aad2c
# ...                                 ...                               ...
# 99436  9c5dedf39a927c1b2549525ed64a053c  39bd1228ee8140590ac3aca26f2dfe00
# 99437  63943bddc261676b46f01ca7ac2f7bd8  1fca14ff2861355f6e5f14306ff977a7
# 99438  83c1379a015df1e13d02aae0204711ab  1aa71eb042121263aafbe80c1b562c9c
# 99439  11c177c8e97725db2631073c19f07b62  b331b74b18dc79bcdf6532d51e1637c1
# 99440  66dea50a8b16d9b4dee7af250b4be1a5  edb027a75a1449115f6b43211ae02a24
#
#       order_status order_purchase_timestamp    order_approved_at  \
# 0        delivered      2017-10-02 10:56:33  2017-10-02 11:07:15
# 1        delivered      2018-07-24 20:41:37  2018-07-26 03:24:27
# 2        delivered      2018-08-08 08:38:49  2018-08-08 08:55:23
# 3        delivered      2017-11-18 19:28:06  2017-11-18 19:45:59
# 4        delivered      2018-02-13 21:18:39  2018-02-13 22:20:29
# ...            ...                      ...                  ...
# 99436    delivered      2017-03-09 09:54:05  2017-03-09 09:54:05
# 99437    delivered      2018-02-06 12:58:58  2018-02-06 13:10:37
# 99438    delivered      2017-08-27 14:46:43  2017-08-27 15:04:16
# 99439    delivered      2018-01-08 21:28:27  2018-01-08 21:36:21
# 99440    delivered      2018-03-08 20:57:30  2018-03-09 11:20:28
#
#       order_delivered_carrier_date order_delivered_customer_date  \
# 0              2017-10-04 19:55:00           2017-10-10 21:25:13
# 1              2018-07-26 14:31:00           2018-08-07 15:27:45
# 2              2018-08-08 13:50:00           2018-08-17 18:06:29
# 3              2017-11-22 13:39:59           2017-12-02 00:28:42
# 4              2018-02-14 19:46:34           2018-02-16 18:17:02
# ...                            ...                           ...
# 99436          2017-03-10 11:18:03           2017-03-17 15:08:01
# 99437          2018-02-07 23:22:42           2018-02-28 17:37:56
# 99438          2017-08-28 20:52:26           2017-09-21 11:24:17
# 99439          2018-01-12 15:35:03           2018-01-25 23:32:54
# 99440          2018-03-09 22:11:59           2018-03-16 13:08:30
#
#       order_estimated_delivery_date
# 0               2017-10-18 00:00:00
# 1               2018-08-13 00:00:00
# 2               2018-09-04 00:00:00
# 3               2017-12-15 00:00:00
# 4               2018-02-26 00:00:00
# ...                             ...
# 99436           2017-03-28 00:00:00
# 99437           2018-03-02 00:00:00
# 99438           2017-09-27 00:00:00
# 99439           2018-02-15 00:00:00
# 99440           2018-04-03 00:00:00
#
# [99441 rows x 8 columns]

# %%
product_category_data = pd.read_csv('/content/E-Commerce Public Dataset/product_category_name_translation.csv')
product_category_data
# Out:
#             product_category_name product_category_name_english
# 0                    beleza_saude                 health_beauty
# 1          informatica_acessorios         computers_accessories
# 2                      automotivo                          auto
# 3                 cama_mesa_banho                bed_bath_table
# 4                moveis_decoracao               furniture_decor
# ..                            ...                           ...
# 66                         flores                       flowers
# 67             artes_e_artesanato         arts_and_craftmanship
# 68                fraldas_higiene           diapers_and_hygiene
# 69  fashion_roupa_infanto_juvenil     fashion_childrens_clothes
# 70             seguros_e_servicos         security_and_services
#
# [71 rows x 2 columns]

# %%
products_data = pd.read_csv('/content/E-Commerce Public Dataset/products_dataset.csv')
products_data
# Out:
#                              product_id              product_category_name  \
# 0      1e9e8ef04dbcff4541ed26657ea517e5                         perfumaria
# 1      3aa071139cb16b67ca9e5dea641aaa2f                              artes
# 2      96bd76ec8810374ed1b65e291975717f                      esporte_lazer
# 3      cef67bcfe19066a932b7673e239eb23d                              bebes
# 4      9dc1a7de274444849c219cff195d0b71              utilidades_domesticas
# ...                                 ...                                ...
# 32946  a0b7d5a992ccda646f2d34e418fff5a0                   moveis_decoracao
# 32947  bf4538d88321d0fd4412a93c974510e6  construcao_ferramentas_iluminacao
# 32948  9a7c6041fa9592d9d9ef6cfe62a71f8c                    cama_mesa_banho
# 32949  83808703fc0706a22e264b9d75f04a2e             informatica_acessorios
# 32950  106392145fca363410d287a815be6de4                    cama_mesa_banho
#
#        product_name_lenght  product_description_lenght  product_photos_qty  \
# 0                     40.0                       287.0                 1.0
# 1                     44.0                       276.0                 1.0
# 2                     46.0                       250.0                 1.0
# 3                     27.0                       261.0                 1.0
# 4                     37.0                       402.0                 4.0
# ...                    ...                         ...                 ...
# 32946                 45.0                        67.0                 2.0
# 32947                 41.0                       971.0                 1.0
# 32948                 50.0                       799.0                 1.0
# 32949                 60.0                       156.0                 2.0
# 32950                 58.0                       309.0                 1.0
#
#        product_weight_g  product_length_cm  product_height_cm  \
# 0                 225.0               16.0               10.0
# 1                1000.0               30.0               18.0
# 2                 154.0               18.0                9.0
# 3                 371.0               26.0                4.0
# 4                 625.0               20.0               17.0
# ...                 ...                ...                ...
# 32946           12300.0               40.0               40.0
# 32947            1700.0               16.0               19.0
# 32948            1400.0               27.0                7.0
# 32949             700.0               31.0               13.0
# 32950            2083.0               12.0                2.0
#
#        product_width_cm
# 0                  14.0
# 1                  20.0
# 2                  15.0
# 3                  26.0
# 4                  13.0
# ...                 ...
# 32946              40.0
# 32947              16.0
# 32948              27.0
# 32949              20.0
# 32950               7.0
#
# [32951 rows x 9 columns]

# %%
sellers_data = pd.read_csv('/content/E-Commerce Public Dataset/sellers_dataset.csv')
sellers_data
# Out:
#                              seller_id  seller_zip_code_prefix  \
# 0     3442f8959a84dea7ee197c632cb2df15                   13023
# 1     d1b65fc7debc3361ea86b5f14c68d2e2                   13844
# 2     ce3ad9de960102d0677a81f5d0bb7b2d                   20031
# 3     c0f3eea2e14555b6faeea3dd58c1b1c3                    4195
# 4     51a04a8a6bdcb23deccc82b0b80742cf                   12914
# ...                                ...                     ...
# 3090  98dddbc4601dd4443ca174359b237166                   87111
# 3091  f8201cab383e484733266d1906e2fdfa                   88137
# 3092  74871d19219c7d518d0090283e03c137                    4650
# 3093  e603cf3fec55f8697c9059638d6c8eb5                   96080
# 3094  9e25199f6ef7e7c347120ff175652c3b                   12051
#
#             seller_city seller_state
# 0              campinas           SP
# 1            mogi guacu           SP
# 2        rio de janeiro           RJ
# 3             sao paulo           SP
# 4     braganca paulista           SP
# ...                 ...          ...
# 3090            sarandi           PR
# 3091            palhoca           SC
# 3092          sao paulo           SP
# 3093            pelotas           RS
# 3094            taubate           SP
#
# [3095 rows x 4 columns]

# %%
geolocation_data = pd.read_csv('/content/E-Commerce Public Dataset/geolocation_dataset.csv')
geolocation_data
# Out:
#          geolocation_zip_code_prefix  geolocation_lat  geolocation_lng  \
# 0                               1037       -23.545621       -46.639292
# 1                               1046       -23.546081       -46.644820
# 2                               1046       -23.546129       -46.642951
# 3                               1041       -23.544392       -46.639499
# 4                               1035       -23.541578       -46.641607
# ...                              ...              ...              ...
# 1000158                        99950       -28.068639       -52.010705
# 1000159                        99900       -27.877125       -52.224882
# 1000160                        99950       -28.071855       -52.014716
# 1000161                        99980       -28.388932       -51.846871
# 1000162                        99950       -28.070104       -52.018658
#
#         geolocation_city geolocation_state
# 0              sao paulo                SP
# 1              sao paulo                SP
# 2              sao paulo                SP
# 3              sao paulo                SP
# 4              sao paulo                SP
# ...                  ...               ...
# 1000158         tapejara                RS
# 1000159   getulio vargas                RS
# 1000160         tapejara                RS
# 1000161  david canabarro                RS
# 1000162         tapejara                RS
#
# [1000163 rows x 5 columns]

# %% [markdown]
# ## Assessing Data

# %% [markdown]
# ### Numeric Data

# %%
cust_desc_num = customers_data.describe().T
geo_desc_num = geolocation_data.describe().T
ord_itm_desc_num = order_items_data.describe().T
ord_pay_desc_num = order_payments_data.describe().T
ord_rvw_desc_num = order_reviews_data.describe().T
ord_desc_num = orders_data.describe().T
prod_cat_desc_num = product_category_data.describe().T
prod_desc_num = products_data.describe().T
sell_desc_num = sellers_data.describe().T

# %%
cust_desc_num['dtype'] = customers_data.select_dtypes('number').dtypes
geo_desc_num['dtype'] = geolocation_data.select_dtypes('number').dtypes
ord_itm_desc_num['dtype'] = order_items_data.select_dtypes('number').dtypes
ord_pay_desc_num['dtype'] = order_payments_data.select_dtypes('number').dtypes
ord_rvw_desc_num['dtype'] = order_reviews_data.select_dtypes('number').dtypes
ord_desc_num['dtype'] = orders_data.select_dtypes('number').dtypes
prod_cat_desc_num['dtype'] = product_category_data.select_dtypes('number').dtypes
prod_desc_num['dtype'] = products_data.select_dtypes('number').dtypes
sell_desc_num['dtype'] = sellers_data.select_dtypes('number').dtypes

# %%
cust_desc_num['null'] = customers_data.select_dtypes('number').isna().sum()
geo_desc_num['null'] = geolocation_data.select_dtypes('number').isna().sum()
ord_itm_desc_num['null'] = order_items_data.select_dtypes('number').isna().sum()
ord_pay_desc_num['null'] = order_payments_data.select_dtypes('number').isna().sum()
ord_rvw_desc_num['null'] = order_reviews_data.select_dtypes('number').isna().sum()
ord_desc_num['null'] = orders_data.select_dtypes('number').isna().sum()
prod_cat_desc_num['null'] = product_category_data.select_dtypes('number').isna().sum()
prod_desc_num['null'] = products_data.select_dtypes('number').isna().sum()
sell_desc_num['null'] = sellers_data.select_dtypes('number').isna().sum()

# %%
cust_desc_num['unique'] = customers_data.select_dtypes('number').nunique()
geo_desc_num['unique'] = geolocation_data.select_dtypes('number').nunique()
ord_itm_desc_num['unique'] = order_items_data.select_dtypes('number').nunique()
ord_pay_desc_num['unique'] = order_payments_data.select_dtypes('number').nunique()
ord_rvw_desc_num['unique'] = order_reviews_data.select_dtypes('number').nunique()
ord_desc_num['unique'] = orders_data.select_dtypes('number').nunique()
prod_cat_desc_num['unique'] = product_category_data.select_dtypes('number').nunique()
prod_desc_num['unique'] = products_data.select_dtypes('number').nunique()
sell_desc_num['unique'] = sellers_data.select_dtypes('number').nunique()

# %%
cust_desc_num['duplicated'] = customers_data.duplicated().sum()
geo_desc_num['duplicated'] = geolocation_data.duplicated().sum()
ord_itm_desc_num['duplicated'] = order_items_data.duplicated().sum()
ord_pay_desc_num['duplicated'] = order_payments_data.duplicated().sum()
ord_rvw_desc_num['duplicated'] = order_reviews_data.duplicated().sum()
ord_desc_num['duplicated'] = orders_data.duplicated().sum()
prod_cat_desc_num['duplicated'] = product_category_data.duplicated().sum()
prod_desc_num['duplicated'] = products_data.duplicated().sum()
sell_desc_num['duplicated'] = sellers_data.duplicated().sum()

# %%
cust_desc_num
# Out:
#                             count          mean           std     min  \
# customer_zip_code_prefix  99441.0  35137.474583  29797.938996  1003.0
#
#                               25%      50%      75%      max  dtype  null  \
# customer_zip_code_prefix  11347.0  24416.0  58900.0  99990.0  int64     0
#
#                           unique  duplicated
# customer_zip_code_prefix   14994           0

# %%
geo_desc_num
# Out:
#                                  count          mean           std  \
# geolocation_zip_code_prefix  1000163.0  36574.166466  30549.335710
# geolocation_lat              1000163.0    -21.176153      5.715866
# geolocation_lng              1000163.0    -46.390541      4.269748
#
#                                      min           25%           50%  \
# geolocation_zip_code_prefix  1001.000000  11075.000000  26530.000000
# geolocation_lat               -36.605374    -23.603546    -22.919377
# geolocation_lng              -101.466766    -48.573172    -46.637879
#
#                                       75%           max    dtype  null  \
# geolocation_zip_code_prefix  63504.000000  99990.000000    int64     0
# geolocation_lat                -19.979620     45.065933  float64     0
# geolocation_lng                -43.767709    121.105394  float64     0
#
#                              unique  duplicated
# geolocation_zip_code_prefix   19015      261831
# geolocation_lat              717360      261831
# geolocation_lng              717613      261831

# %%
ord_itm_desc_num
# Out:
#                   count        mean         std   min    25%    50%     75%  \
# order_item_id  112650.0    1.197834    0.705124  1.00   1.00   1.00    1.00
# price          112650.0  120.653739  183.633928  0.85  39.90  74.99  134.90
# freight_value  112650.0   19.990320   15.806405  0.00  13.08  16.26   21.15
#
#                    max    dtype  null  unique  duplicated
# order_item_id    21.00    int64     0      21           0
# price          6735.00  float64     0    5968           0
# freight_value   409.68  float64     0    6999           0

# %%
ord_pay_desc_num
# Out:
#                          count        mean         std  min    25%    50%  \
# payment_sequential    103886.0    1.092679    0.706584  1.0   1.00    1.0
# payment_installments  103886.0    2.853349    2.687051  0.0   1.00    1.0
# payment_value         103886.0  154.100380  217.494064  0.0  56.79  100.0
#
#                            75%       max    dtype  null  unique  duplicated
# payment_sequential      1.0000     29.00    int64     0      29           0
# payment_installments    4.0000     24.00    int64     0      24           0
# payment_value         171.8375  13664.08  float64     0   29077           0

# %%
ord_rvw_desc_num
# Out:
#                 count      mean       std  min  25%  50%  75%  max  dtype  \
# review_score  99224.0  4.086421  1.347579  1.0  4.0  5.0  5.0  5.0  int64
#
#               null  unique  duplicated
# review_score     0       5           0

# %%
prod_cat_desc_num
# Out:
#                               count  unique            top freq dtype  null  \
# product_category_name            71     NaN   beleza_saude    1   NaN   NaN
# product_category_name_english    71     NaN  health_beauty    1   NaN   NaN
#
#                                duplicated
# product_category_name                   0
# product_category_name_english           0

# %%
ord_desc_num
# Out:
#                                count  unique  \
# order_id                       99441     NaN
# customer_id                    99441     NaN
# order_status                   99441     NaN
# order_purchase_timestamp       99441     NaN
# order_approved_at              99281     NaN
# order_delivered_carrier_date   97658     NaN
# order_delivered_customer_date  96476     NaN
# order_estimated_delivery_date  99441     NaN
#
#                                                             top   freq dtype  \
# order_id                       e481f51cbdc54678b7cc49136f2d6af7      1   NaN
# customer_id                    9ef432eb6251297304e76186b10a928d      1   NaN
# order_status                                          delivered  96478   NaN
# order_purchase_timestamp                    2018-04-11 10:48:14      3   NaN
# order_approved_at                           2018-02-27 04:31:10      9   NaN
# order_delivered_carrier_date                2018-05-09 15:48:00     47   NaN
# order_delivered_customer_date               2018-05-08 23:38:46      3   NaN
# order_estimated_delivery_date               2017-12-20 00:00:00    522   NaN
#
#                                null  duplicated
# order_id                        NaN           0
# customer_id                     NaN           0
# order_status                    NaN           0
# order_purchase_timestamp        NaN           0
# order_approved_at               NaN           0
# order_delivered_carrier_date    NaN           0
# order_delivered_customer_date   NaN           0
# order_estimated_delivery_date   NaN           0

# %%
prod_desc_num
# Out:
#                               count         mean          std  min    25%  \
# product_name_lenght         32341.0    48.476949    10.245741  5.0   42.0
# product_description_lenght  32341.0   771.495285   635.115225  4.0  339.0
# product_photos_qty          32341.0     2.188986     1.736766  1.0    1.0
# product_weight_g            32949.0  2276.472488  4282.038731  0.0  300.0
# product_length_cm           32949.0    30.815078    16.914458  7.0   18.0
# product_height_cm           32949.0    16.937661    13.637554  2.0    8.0
# product_width_cm            32949.0    23.196728    12.079047  6.0   15.0
#
#                               50%     75%      max    dtype  null  unique  \
# product_name_lenght          51.0    57.0     76.0  float64   610      66
# product_description_lenght  595.0   972.0   3992.0  float64   610    2960
# product_photos_qty            1.0     3.0     20.0  float64   610      19
# product_weight_g            700.0  1900.0  40425.0  float64     2    2204
# product_length_cm            25.0    38.0    105.0  float64     2      99
# product_height_cm            13.0    21.0    105.0  float64     2     102
# product_width_cm             20.0    30.0    118.0  float64     2      95
#
#                             duplicated
# product_name_lenght                  0
# product_description_lenght           0
# product_photos_qty                   0
# product_weight_g                     0
# product_length_cm                    0
# product_height_cm                    0
# product_width_cm                     0

# %%
sell_desc_num
# Out:
#                          count          mean          std     min     25%  \
# seller_zip_code_prefix  3095.0  32291.059451  32713.45383  1001.0  7093.5
#
#                             50%      75%      max  dtype  null  unique  \
# seller_zip_code_prefix  14940.0  64552.5  99730.0  int64     0    2246
#
#                         duplicated
# seller_zip_code_prefix           0

# %% [markdown]
# ### Category Data

# %%
cust_desc_cat = customers_data.describe(include='O').T
geo_desc_cat = geolocation_data.describe(include='O').T
ord_itm_desc_cat = order_items_data.describe(include='O').T
ord_pay_desc_cat = order_payments_data.describe(include='O').T
ord_rvw_desc_cat = order_reviews_data.describe(include='O').T
ord_desc_cat = orders_data.describe(include='O').T
prod_cat_desc_cat = product_category_data.describe(include='O').T
prod_desc_cat = products_data.describe(include='O').T
sell_desc_cat = sellers_data.describe(include='O').T

# %%
cust_desc_cat['dtype'] = customers_data.select_dtypes('O').dtypes
geo_desc_cat['dtype'] = geolocation_data.select_dtypes('O').dtypes
ord_itm_desc_cat['dtype'] = order_items_data.select_dtypes('O').dtypes
ord_pay_desc_cat['dtype'] = order_payments_data.select_dtypes('O').dtypes
ord_rvw_desc_cat['dtype'] = order_reviews_data.select_dtypes('O').dtypes
ord_desc_cat['dtype'] = orders_data.select_dtypes('O').dtypes
prod_cat_desc_cat['dtype'] = product_category_data.select_dtypes('O').dtypes
prod_desc_cat['dtype'] = products_data.select_dtypes('O').dtypes
sell_desc_cat['dtype'] = sellers_data.select_dtypes('O').dtypes

# %%
cust_desc_cat['null'] = customers_data.select_dtypes('O').isna().sum()
geo_desc_cat['null'] = geolocation_data.select_dtypes('O').isna().sum()
ord_itm_desc_cat['null'] = order_items_data.select_dtypes('O').isna().sum()
ord_pay_desc_cat['null'] = order_payments_data.select_dtypes('O').isna().sum()
ord_rvw_desc_cat['null'] = order_reviews_data.select_dtypes('O').isna().sum()
ord_desc_cat['null'] = orders_data.select_dtypes('O').isna().sum()
prod_cat_desc_cat['null'] = product_category_data.select_dtypes('O').isna().sum()
prod_desc_cat['null'] = products_data.select_dtypes('O').isna().sum()
sell_desc_cat['null'] = sellers_data.select_dtypes('O').isna().sum()

# %%
cust_desc_cat['unique'] = customers_data.select_dtypes('O').nunique()
geo_desc_cat['unique'] = geolocation_data.select_dtypes('O').nunique()
ord_itm_desc_cat['unique'] = order_items_data.select_dtypes('O').nunique()
ord_pay_desc_cat['unique'] = order_payments_data.select_dtypes('O').nunique()
ord_rvw_desc_cat['unique'] = order_reviews_data.select_dtypes('O').nunique()
ord_desc_cat['unique'] = orders_data.select_dtypes('O').nunique()
prod_cat_desc_cat['unique'] = product_category_data.select_dtypes('O').nunique()
prod_desc_cat['unique'] = products_data.select_dtypes('O').nunique()
sell_desc_cat['unique'] = sellers_data.select_dtypes('O').nunique()

# %%
cust_desc_cat['duplicated'] = customers_data.duplicated().sum()
geo_desc_cat['duplicated'] = geolocation_data.duplicated().sum()
ord_itm_desc_cat['duplicated'] = order_items_data.duplicated().sum()
ord_pay_desc_cat['duplicated'] = order_payments_data.duplicated().sum()
ord_rvw_desc_cat['duplicated'] = order_reviews_data.duplicated().sum()
ord_desc_cat['duplicated'] = orders_data.duplicated().sum()
prod_cat_desc_cat['duplicated'] = product_category_data.duplicated().sum()
prod_desc_cat['duplicated'] = products_data.duplicated().sum()
sell_desc_cat['duplicated'] = sellers_data.duplicated().sum()

# %%
cust_desc_cat
# Out:
#                     count  unique                               top   freq  \
# customer_id         99441   99441  06b8999e2fba1a1fbc88172c00ba8bc7      1
# customer_unique_id  99441   96096  8d50f5eadf50201ccdcedfb9e2ac8455     17
# customer_city       99441    4119                         sao paulo  15540
# customer_state      99441      27                                SP  41746
#
#                      dtype  null  duplicated
# customer_id         object     0           0
# customer_unique_id  object     0           0
# customer_city       object     0           0
# customer_state      object     0           0

# %%
geo_desc_cat
# Out:
#                      count  unique        top    freq   dtype  null  \
# geolocation_city   1000163    8011  sao paulo  135800  object     0
# geolocation_state  1000163      27         SP  404268  object     0
#
#                    duplicated
# geolocation_city       261831
# geolocation_state      261831

# %%
ord_itm_desc_cat
# Out:
#                       count  unique                               top  freq  \
# order_id             112650   98666  8272b63d03f5f79c56e9e4120aec44ef    21
# product_id           112650   32951  aca2eb7d00ea1a7b8ebd4e68314663af   527
# seller_id            112650    3095  6560211a19b47992c3666cc44a7e94c0  2033
# shipping_limit_date  112650   93318               2017-07-21 18:25:23    21
#
#                       dtype  null  duplicated
# order_id             object     0           0
# product_id           object     0           0
# seller_id            object     0           0
# shipping_limit_date  object     0           0

# %%
ord_pay_desc_cat
# Out:
#                count  unique                               top   freq   dtype  \
# order_id      103886   99440  fa65dad1b0e818e3ccc5cb0e39231352     29  object
# payment_type  103886       5                       credit_card  76795  object
#
#               null  duplicated
# order_id         0           0
# payment_type     0           0

# %%
ord_rvw_desc_cat
# Out:
#                          count  unique                               top freq  \
# review_id                99224   98410  7b606b0d57b078384f0b58eac1d41d78    3
# order_id                 99224   98673  c88b1d1b157a9999ce368f218a407141    3
# review_comment_title     11568    4527                         Recomendo  423
# review_comment_message   40977   36159                         Muito bom  230
# review_creation_date     99224     636               2017-12-19 00:00:00  463
# review_answer_timestamp  99224   98248               2017-06-15 23:21:05    4
#
#                           dtype   null  duplicated
# review_id                object      0           0
# order_id                 object      0           0
# review_comment_title     object  87656           0
# review_comment_message   object  58247           0
# review_creation_date     object      0           0
# review_answer_timestamp  object      0           0

# %%
prod_cat_desc_cat
# Out:
#                               count  unique            top freq   dtype  null  \
# product_category_name            71      71   beleza_saude    1  object     0
# product_category_name_english    71      71  health_beauty    1  object     0
#
#                                duplicated
# product_category_name                   0
# product_category_name_english           0

# %%
ord_desc_cat
# Out:
#                                count  unique  \
# order_id                       99441   99441
# customer_id                    99441   99441
# order_status                   99441       8
# order_purchase_timestamp       99441   98875
# order_approved_at              99281   90733
# order_delivered_carrier_date   97658   81018
# order_delivered_customer_date  96476   95664
# order_estimated_delivery_date  99441     459
#
#                                                             top   freq  \
# order_id                       e481f51cbdc54678b7cc49136f2d6af7      1
# customer_id                    9ef432eb6251297304e76186b10a928d      1
# order_status                                          delivered  96478
# order_purchase_timestamp                    2018-04-11 10:48:14      3
# order_approved_at                           2018-02-27 04:31:10      9
# order_delivered_carrier_date                2018-05-09 15:48:00     47
# order_delivered_customer_date               2018-05-08 23:38:46      3
# order_estimated_delivery_date               2017-12-20 00:00:00    522
#
#                                 dtype  null  duplicated
# order_id                       object     0           0
# customer_id                    object     0           0
# order_status                   object     0           0
# order_purchase_timestamp       object     0           0
# order_approved_at              object   160           0
# order_delivered_carrier_date   object  1783           0
# order_delivered_customer_date  object  2965           0
# order_estimated_delivery_date  object     0           0

# %%
prod_desc_cat
# Out:
#                        count  unique                               top  freq  \
# product_id             32951   32951  1e9e8ef04dbcff4541ed26657ea517e5     1
# product_category_name  32341      73                   cama_mesa_banho  3029
#
#                         dtype  null  duplicated
# product_id             object     0           0
# product_category_name  object   610           0

# %%
sell_desc_cat
# Out:
#              count  unique                               top  freq   dtype  \
# seller_id     3095    3095  3442f8959a84dea7ee197c632cb2df15     1  object
# seller_city   3095     611                         sao paulo   694  object
# seller_state  3095      23                                SP  1849  object
#
#               null  duplicated
# seller_id        0           0
# seller_city      0           0
# seller_state     0           0

# %% [markdown]
# # Data Cleaning

# %%
def pretty_string(column):
    column_space = ' '.join(column.split())
    return unidecode.unidecode(column_space.lower())

geolocation_data['geolocation_city'] = geolocation_data['geolocation_city'].apply(pretty_string)

# %%
result_df.sort_values(by=['geolocation_zip_code_prefix', 'geolocation_city'])
# Out:
#        geolocation_zip_code_prefix  geolocation_lat  geolocation_lng  \
# 65                            1307       -23.556812       -46.657135
# 0                             1307       -23.549361       -46.654124
# 1                             1307       -23.555337       -46.655947
# 2                             1307       -23.551046       -46.653077
# 3                             1307       -23.551910       -46.649195
# ...                            ...              ...              ...
# 21198                        97578       -30.867236       -55.493181
# 21199                        97578       -30.870411       -55.481128
# 21200                        97578       -30.856068       -55.496882
# 21201                        97578       -30.865786       -55.501070
# 21202                        97578       -30.865809       -55.493583
#
#             geolocation_city geolocation_state
# 65     sao bernardo do campo                SP
# 0                  sao paulo                SP
# 1                  sao paulo                SP
# 2                  sao paulo                SP
# 3                  sao paulo                SP
# ...                      ...               ...
# 21198  santana do livramento                RS
# 21199  santana do livramento                RS
# 21200  santana do livramento                RS
# 21201  santana do livramento                RS
# 21202  santana do livramento                RS
#
# [21350 rows x 5 columns]
# Warning: total number of rows (21350) exceeds max_rows (20000). Limiting to first (20000) rows.

# %%
drop_duplicate_geo_data = geolocation_data.drop_duplicates().sort_values(by=['geolocation_zip_code_prefix', 'geolocation_city', 'geolocation_state'])
new_geo_data = drop_duplicate_geo_data.groupby(['geolocation_zip_code_prefix'], as_index=False).apply(lambda x: x if len(x)//2 == 0 else x.iloc[[len(x)//2]]).reset_index(level=0, drop=True)
new_geo_data
# Out:
#         geolocation_zip_code_prefix  geolocation_lat  geolocation_lng  \
# 519                            1001       -23.551337       -46.634027
# 516                            1002       -23.548137       -46.635905
# 500                            1003       -23.548976       -46.635322
# 804                            1004       -23.549497       -46.634468
# 584                            1005       -23.549980       -46.634768
# ...                             ...              ...              ...
# 999861                        99960       -27.953409       -52.031394
# 999949                        99965       -28.181715       -52.035593
# 999874                        99970       -28.344122       -51.875680
# 999950                        99980       -28.388400       -51.845225
# 999864                        99990       -28.329472       -51.769109
#
#        geolocation_city geolocation_state
# 519           sao paulo                SP
# 516           sao paulo                SP
# 500           sao paulo                SP
# 804           sao paulo                SP
# 584           sao paulo                SP
# ...                 ...               ...
# 999861          charrua                RS
# 999949       agua santa                RS
# 999874          ciriaco                RS
# 999950  david canabarro                RS
# 999864        muliterno                RS
#
# [19015 rows x 5 columns]
